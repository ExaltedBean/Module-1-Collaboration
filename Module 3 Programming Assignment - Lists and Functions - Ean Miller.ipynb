# %%
things = ['mozzerella', 'cinderella', 'salmonella']
print(things)
# Out:
# ['mozzerella', 'cinderella', 'salmonella']

# %%
things = ['mozzerella', 'Cinderella', 'salmonella']
print(things)
# Out:
# ['mozzerella', 'Cinderella', 'salmonella']

# %% [markdown]
# The element "cinderella"'s caplitalization did change. This shows us that caplitalization matters for variables/elements within lists.

# %%
things = ['MOZERELLA', 'Cinderella', 'salmonella']
print(things)
# Out:
# ['MOZERELLA', 'Cinderella', 'salmonella']

# %%
things = ['MOZERELLA', 'Cinderella', 'salmonella']
del things[2]
print(things)
# Out:
# ['MOZERELLA', 'Cinderella']

# %%
potterNames = ['Harry', 'Ron', 'Hermione']
def good():
    return potterNames
good()
# Out:
# ['Harry', 'Ron', 'Hermione']

# %%
def get_odds():
    for x in range(10):
        if x % 2 != 0:
            yield x
count = 0
for num in get_odds():
    count += 1
    if count == 3:
        print(num)
        break
# Out:
# 5
