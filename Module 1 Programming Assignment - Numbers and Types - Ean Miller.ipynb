# %%
60*60
# Out:
# 3600

# %%
seconds_per_hour = 3600

# %%
seconds_per_hour*24
# Out:
# 86400

# %%
seconds_per_day = seconds_per_hour*24

# %%
seconds_per_day/seconds_per_hour
# Out:
# 24.0

# %%
seconds_per_day//seconds_per_hour
# Out:
# 24

# %% [markdown]
# The numbers agree, they both get the same result regardless of the difference being .0, because .0 holds no value that would change the value of the 24 proceeding it.
